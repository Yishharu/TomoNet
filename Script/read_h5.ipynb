# %%
import h5py

# %%
f = h5py.File('../Runs/seismogram_data.h5','r')

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['disp', 'harmonics', 'station_coords_cartesian', 'station_coords_spherical', 'time']>

# %%
f['station_coords_cartesian'][:]
# Out:
# array([[[ 5.5697054e-01, -4.8691909e-08, -6.3710000e+06],
#         [ 5.4850888e-01,  9.6716978e-02, -6.3710000e+06],
#         [ 5.2338111e-01,  1.9049518e-01, -6.3710000e+06],
#         ...,
#         [ 5.2338111e-01, -1.9049518e-01, -6.3710000e+06],
#         [ 5.4850888e-01, -9.6716978e-02, -6.3710000e+06],
#         [ 5.5697054e-01,  4.8691909e-08, -6.3710000e+06]],
#
#        [[-1.1063132e+06,  9.6716978e-02, -6.2742100e+06],
#         [-1.0895059e+06, -1.9210939e+05, -6.2742100e+06],
#         [-1.0395944e+06, -3.7838150e+05, -6.2742100e+06],
#         ...,
#         [-1.0395944e+06,  3.7838150e+05, -6.2742100e+06],
#         [-1.0895059e+06,  1.9210939e+05, -6.2742100e+06],
#         [-1.1063132e+06, -9.6716978e-02, -6.2742100e+06]],
#
#        [[-2.1790108e+06,  1.9049516e-01, -5.9867815e+06],
#         [-2.1459068e+06, -3.7838147e+05, -5.9867815e+06],
#         [-2.0476004e+06, -7.4526575e+05, -5.9867815e+06],
#         ...,
# ...

# %%
f['station_coords_spherical'][:]
# Out:
# array([[[ 3.1415927e+00, -3.1415927e+00,  6.3710000e+06],
#         [ 3.1415927e+00, -2.9670596e+00,  6.3710000e+06],
#         [ 3.1415927e+00, -2.7925267e+00,  6.3710000e+06],
#         ...,
#         [ 3.1415927e+00,  2.7925267e+00,  6.3710000e+06],
#         [ 3.1415927e+00,  2.9670596e+00,  6.3710000e+06],
#         [ 3.1415927e+00,  3.1415927e+00,  6.3710000e+06]],
#
#        [[ 2.9670596e+00, -3.1415927e+00,  6.3710000e+06],
#         [ 2.9670596e+00, -2.9670596e+00,  6.3710000e+06],
#         [ 2.9670596e+00, -2.7925267e+00,  6.3710000e+06],
#         ...,
#         [ 2.9670596e+00,  2.7925267e+00,  6.3710000e+06],
#         [ 2.9670596e+00,  2.9670596e+00,  6.3710000e+06],
#         [ 2.9670596e+00,  3.1415927e+00,  6.3710000e+06]],
#
#        [[ 2.7925267e+00, -3.1415927e+00,  6.3710000e+06],
#         [ 2.7925267e+00, -2.9670596e+00,  6.3710000e+06],
#         [ 2.7925267e+00, -2.7925267e+00,  6.3710000e+06],
#         ...,
# ...
